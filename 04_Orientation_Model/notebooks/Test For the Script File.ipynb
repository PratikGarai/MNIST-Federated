# %%
from dataset import MNISTDataset, Dataset

# %%
d = MNISTDataset(4)

# %%
d.printSlice(3, 3)
# Out:
# [0, 1, 1, 2, 0, 0, 1, 3, 3]

# %%
d.save("saveTest")

# %%
c = MNISTDataset()
c.load("saveTest")
d.printSlice(3, 3)
# Out:
# [0, 1, 1, 2, 0, 0, 1, 3, 3]
